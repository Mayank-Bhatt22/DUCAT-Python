# %%
# to see all the pips
pip freeze
# Out:
# altair==5.5.0
# annotated-types==0.7.0
# anyio==4.4.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==24.2.0
# babel==2.16.0
# beautifulsoup4==4.12.3
# bleach==6.1.0
# blinker==1.8.2
# branca==0.8.1
# cachetools==5.5.1
# certifi==2024.7.4
# cffi==1.17.0
# charset-normalizer==3.3.2
# click==8.1.7
# colorama==0.4.6
# comm==0.2.2
# comtypes==1.4.7
# contourpy==1.3.0
# cycler==0.12.1
# debugpy==1.8.5
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.8
# et-xmlfile==1.1.0
# executing==2.0.1
# fastjsonschema==2.20.0
# filelock==3.16.1
# Flask==3.0.3
# folium==0.20.0
# fonttools==4.53.1
# fqdn==1.5.1
# gitdb==4.0.12
# GitPython==3.1.44
# google-ai-generativelanguage==0.6.15
# google-api-core==2.25.1
# google-api-python-client==2.174.0
# google-auth==2.40.3
# google-auth-httplib2==0.2.0
# google-generativeai==0.8.5
# googleapis-common-protos==1.70.0
# grpcio==1.73.1
# grpcio-status==1.71.0
# h11==0.14.0
# httpcore==1.0.5
# ...

# %%
# import pandas
import pandas as pd

# %%
# to load the dataset by writeing pd.read then tad to select file type then (r"file path in it")
pd.read_csv(r"C:\Users\user\OneDrive\Desktop\New Dataset Ducat\DQL_Selse_Data.csv")
# Out:
#       Sale_Date Customer Name        City        State Region  \
# 0    03-02-2023         Meera      Nagpur  Maharashtra   West
# 1    21-04-2023        Vihaan  Coimbatore   Tamil Nadu  South
# 2    21-09-2023       Nishant   Bengaluru    Karnataka  South
# 3    24-08-2023        Vihaan     Madurai   Tamil Nadu  South
# 4    24-03-2023         Aditi      Mumbai  Maharashtra   West
# ..          ...           ...         ...          ...    ...
# 995  15-04-2023          Riya  Coimbatore   Tamil Nadu  South
# 996  07-09-2023        Ishita      Nagpur  Maharashtra   West
# 997  27-04-2023         Kabir   Bengaluru    Karnataka  South
# 998  20-12-2023        Ananya   Bengaluru    Karnataka  South
# 999  16-08-2023         Kabir      Mumbai  Maharashtra   West
#
#     Product Category Product Name  Quantity  Price per Unit  Sales Amount
# 0          Furniture        Table         6         4016.25      24097.50
# ...

# %%
pd.read_excel(r"C:\Users\user\OneDrive\Desktop\New Dataset Ducat\sales data.xlsx",sheet_name="Sheet1")
# Out:
#      Sale_Date Customer Name        City        State Region Product Category  \
# 0   2023-02-03         Meera      Nagpur  Maharashtra   West        Furniture
# 1   2023-04-21        Vihaan  Coimbatore   Tamil Nadu  South       Stationery
# 2   2023-09-21       Nishant   Bengaluru    Karnataka  South       Stationery
# 3   2023-08-24        Vihaan     Madurai   Tamil Nadu  South         Clothing
# 4   2023-03-24         Aditi      Mumbai  Maharashtra   West        Groceries
# ..         ...           ...         ...          ...    ...              ...
# 995 2023-04-15          Riya  Coimbatore   Tamil Nadu  South        Groceries
# 996 2023-09-07        Ishita      Nagpur  Maharashtra   West        Furniture
# 997 2023-04-27         Kabir   Bengaluru    Karnataka  South         Clothing
# 998 2023-12-20        Ananya   Bengaluru    Karnataka  South       Stationery
# 999 2023-08-16         Kabir      Mumbai  Maharashtra   West         Clothing
#
# ...

# %% [markdown]
# # User Define Module

# %%
import add

# %%
add.addition(4,5,6)
# Out:
# 15

# %%
from add import addition

# %%
addition(3,4)
# Out:
# 7

# %%
import Calcy

# %%
Calcy.add(5,4,6)
# Out:
# 15

# %%
Calcy.sub(1,2)
# Out:
# -1

# %%
Calcy.multiply(2,3)
# Out:
# 6

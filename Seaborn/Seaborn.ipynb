# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')
iris=sns.load_dataset('iris')
flights=sns.load_dataset('flights')
penguins=sns.load_dataset('flights')

# %%
sns.histplot(tips['total_bill'],kde=True,color='g')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips['total_bill'],kde=True,color='g',bins=10)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.countplot(x=tips['day'],palette='mako')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26436\428218203.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=tips['day'],palette='mako')
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x=tips['day'],palette=['y','g','b','r'],edgecolor='k')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26436\901771228.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=tips['day'],palette=['y','g','b','r'],edgecolor='k')
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26436\4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],hist=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26436\1003009286.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],hist=False)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Scatter plot

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex',size='size',style='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

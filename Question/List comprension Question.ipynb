# %% [markdown]
# List comprension
#
# 2. Create a new list that contains only even numbers from a given list.
#
# List: [10, 15, 20, 25, 30]
#
# 3. Extract all names that start with the letter ‘A’ using list comprehension.
#
# List: ["Amit", "Rahul", "Anuj", "Sahil", "Aman"]
#
# 4. Convert all strings in a list to uppercase using list comprehension.
#
# List: ["python", "data", "ml", "sql"]
#
# 5. From a list of numbers, create a list of tuples where each tuple contains (number, square).
#
# List: [1, 2, 3, 4, 5]
#
# 6. Extract all vowels from a given string using list comprehension.
#
# String: "Artificial Intelligence"
#
# 7. Generate a list of numbers from 1 to 50 that are divisible by both 3 and 5.
#
# 8. From a list of words, select only those whose length is greater than 4.
#
# List: ["data", "science", "sql", "python", "ai"]
#
# 9. Build a list of cubes for numbers from 1 to 10 using nested list comprehension.
#
# 10. Convert a dictionary into a list of key-value pair tuples using list comprehension.
#
# Dict: { "a": 1, "b": 2, "c": 3 }
#
# 11. Flatten a 2D list into a 1D list using list comprehension.
#
# List: [[1, 2], [3, 4], [5, 6]]
#
# 12. Create a list of numbers from 1 to 100 but label them as "Even" or "Odd" using list comprehension.
#
# Example output: [("1", "Odd"), ("2", "Even"), ...]

# %% [markdown]
# ASSIGNMENT - SET_TUPLE
# Note: - Tuples And Sets in Python, divided into various categories to cover
# different scenarios and concepts.
# Basic Concepts
# 1. What is a tuple in Python?
# 2. What is a set in Python?
# 3. How do you create a tuple in Python?
# 4. How do you create a set in Python?
# 5. Can a tuple contain elements of different data types?
# 6. Can a set contain elements of different data types?
# 7. What is the syntax to create an empty tuple?
# 8. What is the syntax to create an empty set?
# 9. How do you access elements in a tuple?
# 10. Can you access elements in a set using an index? Why or why not?
# Operations and Methods
# 11. How do you concatenate two tuples?
# 12. How do you add an element to a set?
# 13. How do you remove an element from a tuple?
# 14. How do you remove an element from a set?
# 15. What is the difference between discard() and remove() methods in sets?
# 16. How do you find the length of a tuple?
# 17. How do you find the length of a set?
# 18. How do you check if an element exists in a tuple?
# 19. How do you check if an element exists in a set?
# 20. How do you unpack a tuple into variables?
# Advanced Operations
# 21. How do you perform set union in Python?
# 22. How do you perform set intersection in Python?
# 23. How do you perform set difference in Python?
# 24. How do you perform set symmetric difference in Python?
# 25. What does the frozenset() function do in Python?
# 26. Can you nest a tuple inside a set? Explain.
# 27. Can you nest a set inside a tuple? Explain.
# 28. How do you convert a list to a tuple?
# 29. How do you convert a list to a set?
# 30. How do you convert a tuple to a set?
# Mutability and Immutability
# 31. Are tuples mutable or immutable? Explain with an example.
# 32. Are sets mutable or immutable? Explain with an example.
# 33. What happens if you try to modify an element of a tuple?
# 34. What happens if you try to modify an element of a set?
# 35. What are the benefits of using an immutable data structure like a tuple?
# 36. What are the benefits of using a mutable data structure like a set?
# Use Cases
# 37. When would you use a tuple instead of a list?
# 38. When would you use a set instead of a list?
# 39. How can tuples be useful in function return values?
# 40. How can sets be useful in membership testing?
# 41. Explain a scenario where a tuple can be used as a dictionary key.
# 42. Explain a scenario where a set can be used to remove duplicates from a list.
# Performance Considerations
# 43. How do tuples compare to lists in terms of performance?
# 44. How do sets compare to lists in terms of performance for membership tests?
# 45. What is the time complexity of checking for an element in a tuple?
# 46. What is the time complexity of checking for an element in a set?
# Built-in Functions
# 47. What does the tuple() function do?
# 48. What does the set() function do?
# 49. How do you use the max() function with a tuple?
# 50. How do you use the max() function with a set?
# 51. How do you use the min() function with a tuple?
# 52. How do you use the min() function with a set?
# 53. What does the sum() function do when applied to a tuple of numbers?
# 54. What does the sum() function do when applied to a set of numbers?
# Iteration
# 55. How do you iterate over the elements of a tuple?
# 56. How do you iterate over the elements of a set?
# 57. Can you modify a set while iterating over it? Explain with an example.
# 58. Can you modify a tuple while iterating over it? Explain with an example.
# Tuple and Set Comprehensions
# 59. Explain tuple comprehension and provide an example.
# 60. Explain set comprehension and provide an example.
# Common Errors
# 61. What happens if you try to add a list to a set?
# 62. What happens if you try to use a mutable element in a tuple?
# 63. What happens if you try to access a non-existent index in a tuple?
# 64. What happens if you try to access a non-existent element in a set?
# Applications
# 65. How can you use a tuple to swap values of two variables?
# 66. How can you use a set to find unique elements in a list?
# 67. Explain how to use tuples in sorting.
# 68. Explain how to use sets in filtering.
# Python Specific Features
# 69. What is tuple packing? Give an example.
# 70. What is tuple unpacking? Give an example.
# 71. How do you create a named tuple in Python?
# 72. What is the purpose of the add() method in sets?
# 73. What is the purpose of the update() method in sets?
# 74. How do you convert a string to a tuple of characters?
# 75. How do you convert a string to a set of characters?
# Nested Structures
# 76. Can you have a tuple of tuples? Provide an example.
# 77. Can you have a set of sets? Explain why or why not.
# 78. How do you flatten a tuple of tuples?
# 79. How do you flatten a set of sets?
# Practical Exercises
# 80. Write a Python program to count the number of occurrences of each element in a
# tuple.
# 81. Write a Python program to remove duplicates from a tuple.
# 82. Write a Python program to find the second largest element in a tuple.
# 83. Write a Python program to count the number of vowels in a string using sets.
# 84. Write a Python program to merge two sets and remove any duplicates.
# 85. Write a Python program to find the common elements in two sets.
# 86. Write a Python program to find the elements that are in one set but not in another.
# 87. Write a Python program to check if a set is a subset of another set.
# 88. Write a Python program to check if a set is a superset of another set.
# Interview Questions
# 89. Explain the difference between tuples and lists.
# 90. Explain the difference between sets and dictionaries.
# 91. What is the hashability requirement for set elements and tuple elements?
# 92. How does Python handle memory allocation for tuples and sets?
# 93. Discuss the immutability of tuples and its impact on performance.
# 94. Discuss the mutability of sets and its impact on performance.
# Real-world Applications
# 95. Describe a real-world scenario where you would use a tuple.
# 96. Describe a real-world scenario where you would use a set.
# 97. How can tuples be used in a database query result?
# 98. How can sets be used in text analysis?
# 99. Explain how you can use tuples for structured data storage.
# 100. Explain how you can use sets for fast membership testing.
# Miscellaneous
# 101. What are named tuples and how are they different from regular tuples?
# 102. What is the difference between shallow copying and deep copying a set?
# 103. Can you store a tuple inside a set? Why or why not?
# 104. How do sets handle duplicate elements?
# 105. What are the differences between a frozenset and a regular set?
# 106. Why can't you use a set as a key in a dictionary?

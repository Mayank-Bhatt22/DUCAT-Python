# %% [markdown]
# # Module
#
# 1. **Builtin Module**
# 2. **User Define**
# 3. **Labirary**

# %% [markdown]
# # Keyword

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Time

# %%
import time as t

# %%
t.time()
# Out:
# 1763636483.0856717

# %%
t.ctime()
# Out:
# 'Thu Nov 20 16:31:57 2025'

# %%
t.ctime(1763636483.0856717)
# Out:
# 'Thu Nov 20 16:31:23 2025'

# %%
print("hello")
t.sleep(4)
print("hello bhai")
# Out:
# hello
# hello bhai

# %%
start_time=t.time()
c = 0
for i in range(1000000):
    c+=1
print(c)
end_time=t.time()
difference=end_time-start_time
print(difference)
# Out:
# 1000000
# 0.16636252403259277

# %% [markdown]
# # Math

# %%
import math

# %%
# help(math)

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.exp(10)
# Out:
# 22026.465794806718

# %%
math.e
# Out:
# 2.718281828459045

# %%
2.718281828459045**10
# Out:
# 22026.465794806703

# %%
math.gcd(12,18,30)
# Out:
# 6

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pi
# Out:
# 3.141592653589793

# %%
# Random

# %%
import random

# %%
random.random()
# Out:
# 0.4453891822443605

# %%
random.randint(1,100)
# Out:
# 33

# %%
random.randrange(1,20,2)
# Out:
# 13

# %%
random.choice([2,3,4,5,6,7,8])
# Out:
# 4

# %%
random.sample([2,45,3,45,43,34,56,77],2)
# Out:
# [34, 2]

# %%
L = [1,2,4,5,6,7,8]
random.shuffle(L)
print(L)
# Out:
# [8, 7, 6, 5, 4, 1, 2]

# %% [markdown]
# # String

# %%
import string

# %%
#help(string)

# %%
print(string.ascii_letters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
print(string.ascii_lowercase)
# Out:
# abcdefghijklmnopqrstuvwxyz

# %%
print(string.ascii_uppercase)
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
string.digits
# Out:
# '0123456789'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# # Assignment
# 1. datetime
# 2. os
# 3. sys

# %% [markdown]
# # Datetime

# %%
from datetime import datetime

# %%
# help(datetime)

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 11, 21, 0, 1, 8, 138545)

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 11, 21, 0, 1, 49, 557924)

# %%
#

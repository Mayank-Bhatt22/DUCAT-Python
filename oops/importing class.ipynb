# %%
from class1 import Hello
# Out:
# This is my first oops program.

# %%
import class1

# %%
from class2 import Person

# %%
Person.name
# Out:
# 'Mayank Bhattt'

# %%
Person.gender
# Out:
# 'M'

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': 'class2',
#               'name': 'Mayank Bhattt',
#               'age': 20,
#               'gender': 'M',
#               'address': 'Delhi',
#               'contact': 9971106956,
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None})

# %%
from class3 import Student

# %%
S1=Student(1,"Mayank","java",9971106956)
S2=Student(2,"ayank","ava",971106956)
S3=Student(3,"yank","va",71106956)

# %%
S1.name
# Out:
# 'Mayank'

# %%
S2.contact
# Out:
# 971106956

# %%
S1.get_detail()
# Out:
# {'Roll_No': 1, 'Name': 'Mayank', 'Course': 'java', 'contact': 9971106956}

# %%
S2.get_detail()
# Out:
# {'Roll_No': 2, 'Name': 'ayank', 'Course': 'ava', 'contact': 971106956}

# %%
S3.get_detail()
# Out:
# {'Roll_No': 3, 'Name': 'yank', 'Course': 'va', 'contact': 71106956}

# %%
import class4

# %%
from class4 import Person

# %%
p1 = Person(1,"Mayank",'M',20,9971106956,"Sant Nager Burari Delhi-84")

# %%
p1.p_id
# Out:
# 1

# %% [markdown]
# # Getattr TO GET

# %%
getattr(p1,"name")
# Out:
# 'rohit'

# %% [markdown]
# # Setattr TO CHANGE SOMETHING

# %%
setattr(p1,'name','rohit')

# %% [markdown]
# # Delattr TO DELETE

# %%
delattr(p1,"age")

# %% [markdown]
# # Hasattr TO SEE IF OBJECT EXIST

# %%
hasattr(p1,"age")
# Out:
# False

# %%
p1.detail() #( TO SEE THE DETAIL )

# %%
p1.__dict__
# Out:
# {'p_id': 1,
#  'name': 'rohit',
#  'gender': 'M',
#  'contact': 9971106956,
#  'address': 'Sant Nager Burari Delhi-84'}
